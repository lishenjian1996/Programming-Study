# %% [markdown]
# # Basics of factor investing

# %% [markdown]
# Macro-factors are relevant across asset classes, such as GDP growth, Real rate, Inflation, etc.

# %% [markdown]
# Micro-factors are relevant within asset classes, such as Value, Size, Momentum, Low volume, etc for Equities.

# %% [markdown]
# Many savy institutional investors have been <mark> Shifting to Alternatives
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Introducing Factor Models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# epsilon is the residual component
# alpha is often called abnormal return
#
# In CAPM, the alpha is consider in 0

# %% [markdown]
# Question:
# Assume that the explanatory power, or R2, of a multi-variate regression of a stock excess return on excess return of a set of factor is 62%. What is in this case the percentage of risk of the stock that can be regarded as specific or idiosyncratic risk?
#
# Answer:
# The explanatory power, or R2, is the part of the variance explained by the factor model, so 100%-62%=38% is the part of the variance that is not explained by the factor model, and that can therefore be regarded as specific risk (assuming that the factor model is well specified).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Typology of factor models

# %% [markdown]
# Equity factors:
# 1. Market factor
# 2. Value factor
# 3. Size factor
# 4. Momentum factor

# %% [markdown]
# Other factors: Low vol factor, Liquidity factor, Quality factor, etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question:
# What types of stocks have been found to earn a higher return?
#
# Answer: <mark>High book-to-market, small cap, past winners</mark>, because: Low book to market stocks, also known as growth stocks, have been found to underperform high book-to-market stocks, also known as value stocks, large cap stocks have been found to underperform small cap stocks, and past losers have been found to underperform pat winners

# %% [markdown]
# # Using factor models in portfolio construction and analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The use of risk factors improves the consistency of portfolio construction
#
# It's True, because the nature of portfolio construction is to improve both rewards (expected performance) and diversification. Thus, if two securities share common risk factors, the resulting portfolio construction algorithm should be aware of these relationships for consistency purposes.

# %% [markdown]
# # Penalty methods (in Machine Learning)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ridge Regression Penalty:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Lasso:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cross validation with regularized regression:
#
# ![image.png](attachment:image.png)
