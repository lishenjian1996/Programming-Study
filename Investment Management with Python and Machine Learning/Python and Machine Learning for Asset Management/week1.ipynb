# %% [markdown]
# # Machine learning applied in Financial area
# 1. Identify characteristics for defaulting on a loan during a recession
# 2. Ethical/Privacy and regulatory issues
# 3. Large number of individuals (might not use machine learning properly such as fake news)
#
# # Supervised learning
# Machine learning operates on a large number of features
# which perhaps more systematic than humans
# Because Humans apply intuition and vast experience
# Therefore, machine learning computers apply multiple algorighms with a large number of features.

# %% [markdown]
# # First algorithms
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In most explanations of machine learning, it is discussed that three types of data are needed: 1) training data, 2) evaluation data, and 3) test data.  The first two are part of the train-and-test approach.  And the third category – test data – should be only employed to indicate the final reliability of the machine learning algorithm.
# To my mind, it is too much to ask for a single final test stage in the area of financial economics and investment management.  The financial rewards are too high to expect perfection here.  As a consequence, the only true measure is the ex post performance over long time periods. The large level of uncertainty, compared with the low latency of the signal, causes the testing process to be conducted over a long time horizon.

# %% [markdown]
# Keep in mind and practice, practice and practice not only for machine learning also for this course.

# %% [markdown]
# # Highlights of best practice
#
# Ensemble forecasts are superior to a single forecasting model when the aggregation of weak classifiers is better than the forecast of a single strong classifier

# %% [markdown]
# What are the advantages of the train-and-test procedures?
#
# Answer: The traditional statistical methods such as linear regression and econometrics made a number of assumptions about model structure and employed as much historical data as possible.   Machine learning, on the other hand, employs the data without many assumptions about model structure. This approach requires much more data than earlier methods, but it provides more reliable algorithms for classification in many situations.
# The train-and-test procedures are employed to calculate the (hyper-parameters) of a model via out-of-sample data and to reduce the chances of overfitting.  As we have mentioned, a model that fits the data perfectly in-sample is often unable to do well with out of sample data.  Thus, the train-and-test procedure is helpful in reducing overfitting.

# %% [markdown]
# Ensemble methods: combine weak classifiers into a strong classifier which to build a more robust classification.

# %% [markdown]
# # Unsupervised learning

# %% [markdown]
# What is the primary goal of unsupervised learning? Multiple responses possible?
#
# Answer: Unsupervised learning is aimed at discovering patterns in data that have significant implications for individuals and businesses.
#
# For instance, if a person is searching for a restaurant recommendation, she might favor a certain type of food, say Italian, on her vacation days, as compared with work days.  This pattern may be evident in the historical data, and could lead to improving the recommendation system and the ensuring decision.
#
# Another example would be discovering patterns in purchasing. To this end, we might find that one can find better airline ticket prices on Tuesday evenings.  Given this information, we could take advantage of this pattern and reduce our purchase prices.

# %% [markdown]
# # Challenge ahead

# %% [markdown]
# What are potential and actual successes of reinforcement learning?Multiple responses possible？
#
# Answer: The area of reinforcement learning has gained much credibility and renown since the fast and powerful successes of the DeepMind team at Google with their software systems that created the world’s most powerful systems for playing chess, shogi, and go. This remarkable system requires no domain specific information about the game.  Instead, it simply “watches” each of these gains over a carefully curated set of experiments.
# The product selection problem has similar characteristics in terms of its potential application of reinforcement learning.  However, this area is much less structured that zero-sum games.  And accordingly, there is controversy about the degree of success of reinforcement learning.

# %% [markdown]
# # Lab session optimal portfolio

# %% [markdown]
# <mark>Dropping data
#
# There are three options mentioned in the notebook (Section 1) for how to deal with missing data:
#
# i) select the subset that includes all variables (or columns), i.e. dropping rows with missing data;
#
# ii) select the subset that includes all dates (or rows), i.e. dropping columns missing data;
#
# iii) fill in the missing data from other sources or by backfilling. Therefore, answer choices A, B, and C are all correct, and we should choose the answer choice D, all of the above, as our final answer.

# %% [markdown]
# <mark>Changing data frequency
#
# To change the data frequency of the dataframe (for example, converting daily data to weekly data), we should use the “resample” function from the Pandas package (and this is explained in Section 1 of the notebook).

# %%
# Convert daily return data to weekly return
#df_week = (df+1).resample('W').prod() - 1
#df_week = df_week.drop(df_week.index[[0]]) #mannually remove the returns data for the first week
#df_week = df_week.drop(df_week.index[[-1]]) #mannually remove the returns data for the last week
#display(df_week)
