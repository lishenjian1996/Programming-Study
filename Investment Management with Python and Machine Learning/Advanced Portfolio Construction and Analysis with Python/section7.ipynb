# %% [markdown]
# # Portfolio Optimization in Practice

# %% [markdown]
# Mean goal: Well-balanced portfolio
#
# End goal: Well-rewarded portfolio

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What is the effective number of constituents for a portfolio invested at 50% on stock 1 and 50% in stock 2?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Effective Number of Constituents (ENC)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q:
#
# What is the effective number of constituents (ENC) for a portfolio invested 20% in a 20% volatility asset and 80% in a 10% volatility asset, assuming that these assets are uncorrelated?
#
#
# A: 1/(20%^2+80%^2)=1.47

# %% [markdown]
# Improving GMV Portfolios

# %% [markdown]
# Solution #1:
# GMV with minimum ENC
#
# Solution #2:
# Impose that all assets have the same volatility
# ![image.png](attachment:image.png)
#
# Q: If all assets have the same volatility, the max decorrelation portfolio is identical to <mark>the minimum vatriance portfolio<mark>
#
# Answer: Global minimum variance portfolios tend to overweight assets with the lowest volatility levels. The max decorrelation portfolio fixes the problem by imposing that all assets have the same volatility.

# %% [markdown]
# # Measuring risk contributions

# %% [markdown]
# Short coming of ENC
#
# 50% in 30% VOL STOCK
# 50% in (10%) VOL BOND
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Simplified risk parity portfolios

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question: Assume an annualized volatility of 15.1% on a broad equity index and annualized volatility of 4.6% on a broad bond index, with a 0.2 correlation. What is the ENCB for the 60/40 portfolio?
#
# Answer:
# Based on these inputs, it is easy to check that portfolio variance is equal to 0.0092, and that stocks contributed 93% of that risk while bonds contributed the remaining 7% for a 60/40 portfolio. As a result, we obtain:
# ![image.png](attachment:image.png)
