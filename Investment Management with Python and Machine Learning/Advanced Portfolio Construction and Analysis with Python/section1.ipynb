# %% [markdown]
# # Introduction to factor investing

# %% [markdown]
# Indicization refers to the trend of creating new indices that capture the portion of active management that is rules based and systematic, and in the long run should outperform the cap-weighted benchmark

# %% [markdown]
# A Factor is a variable which influences the Returns of Assets
#
# It represents commonality in the returns something outside of the individual asset
#
# Exposure to Factor Risk over the long run yields a reward. The risk premium
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Factor models and the CAPM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If a factor model is a good and accurate representation of what we see in the data, the epsilon term will be LOW, because the <mark>Epsilon in the factor model refers to the error term, and is a measure of what might be in the data that is not captured by the factor model.</mark>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The Anomalies only relative to the CAPM.

# %% [markdown]
# According to the CAPM, the alpha term in the CAPM Factor Model is 0
#
# The CAPM predicts that the alpha term is zero

# %% [markdown]
# <mark>Alpha term is going to be some fixed component.</mark>

# %% [markdown]
# # Multi-Factor models and Fama-French

# %% [markdown]
# A Manager tells you that he concentrates his portfolio in Value stocks because Value outperforms Growth, and his portfolio has outperformed the S&P500 for the last 3 years. Assuming his statements are all True, then If the manager does not show style drift AND the Value Factor generates a positive risk premium the next year, THEN the manager is likely to outperform, but it is not a certainty.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Original Fama French Factor (1993) Model is a THREE factor model where the factors are Market, Value and Size

# %% [markdown]
# # Factor benchmarks and Style analysis

# %% [markdown]
# Assume the risk free rate is 1% per year and the Stock Market returned 11% in a given year. An Active Manager “beat the market” and generated a 14% return and had a Beta of 1.3:
#
#  The excess return of the manager (14% - 1% = 13%) is exactly equal to the beta times the excess return of the market (1.3x(11-1)), the alpha is <MARK>0</MARK>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For Sharpe Style Analysis, the coefficients that we compute are constrained to sum to 1. This is done so that: They can be interpreted as portfolio weights in the explanatory indices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# REFERENCE: https://github.com/gmineo/Advanced-Portfolio-Construction-and-Analysis-with-Python/tree/main
