# %% [markdown]
# # Robust estimates for expected returns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Consider 3 assets with sample means equal to 10%, 15% and 20%, and assume a shrinkage factor d=50%. What is the shrinkage estimator for the expected return on these 3 assets?
#
# A:
#
# Grand mean = (10%+15%+20%)/3 = 15%.
#
# Shrinkage estimator for asset 1: 50% x 10% + 50% x 15% = 12.5%.
#
# Shrinkage estimator for asset 2: 50% x 15% + 50% x 15% = 15%.
#
# Shrinkage estimator for asset 3: 50% x 20% + 50% x 15% = 17.5%.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Agnostic Priors on Expected Return Estimates

# %% [markdown]
# Q:
#
# What is the Sharpe ratio of a portfolio of an equally-weighted portfolio of two stocks with volatility respectively equal to 20% and 30%, and a pairwise correlation 0.6, assuming that they both have a 70% Sharpe ratio?
#
# A:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q:
#
# Assume that a stock index and a bond index have the same Sharpe ratio, and that this common Sharpe ratio is equal to 50%. Further assume that interest rate is 2% and that stock index volatility is 20% and bond index volatility is 10%.
#
# A:
#
# Excess expected return on stock is 50%x20%=10%, and expected return is therefore 10%+2%=12%.
#
# In the same way, excess expected return on stock is 50%x10%=5%, and expected return is 5%+2%=7%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using Factor Models to Estimate Expected Returns

# %% [markdown]
# Q:
#
# Assume that a stock has an expected return of 13% and a volatility of 20%. Further assume that the risk-free rate is 3%, and the stock beta is 1. What is the Sharpe ratio (SR) and Treynor ratio (TR) for this stock?
#
# A:
#
# SR=(13%-3%)/20%=0.5=50% and TR=(13%-3%)/1=10%.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q:
#
# Assume that last year volatility is 20% and last year performance is 15% for stock 1, while it is 30% and 18% respectively for stock 2. Further assume that stock 1 beta is 1.1 and stock 2 beta is 0.8. Which stock should have the highest expected return is the CAPM is correct?
#
# A:
#
# According to CAPM, differences in betas, and differences in betas alone, explain differences in expected returns. Stock 1 therefore should have the highest expected return since it has the highest beta, even though it has a lower volatility (presumably because of a lower amount of specific risk) and even though it has enjoyed a lower performance last year (which tells us close to nothing).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q:
#
# Assume that a stock has a beta of 1 with respect to factor 1 and a beta of 0.5 with respect to factor 2. Further assume that the excess expected return is 6% on factor 1 and 8% on factor 2, and that the risk-free rate is 2%.  What is the expected return on the stock, assuming that these two factors are the only rewarded factors?
#
# A:
#
# According to APT, we have that the excess expected return on the stock is equal to 1x6%+.5x8%=10%, and the expected return is therefore 10%+2%=12%.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Extracting Implied Expected Returns

# %% [markdown]
# The neutral prior distribution is obtained by Reverse engineering assuming market or benchmark is the Optimal Portfolio
#
# Q:
#
# Assume two uncorrelated stocks with volatility 10% and 15% respectively. Further assume that the risk-free rate is 0%. What can we say about the neutral expected returns consistent with an equally-weighted benchmark portfolio?
#
# A:
#
# The second stock must have an expected return 2.25 higher than the expected return of the first stock
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
