# %% [markdown]
# # Making recommendations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using per-item features

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
