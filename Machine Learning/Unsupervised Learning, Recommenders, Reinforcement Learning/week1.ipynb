# %% [markdown]
# Unsupervised Learning
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Clustering
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # K-means intuition

# %% [markdown]
# 30 unlabeled points
#
# K means repeately do two different things.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# repeat step 1 and step 2 again until red cross and blue cross centroids near the mean of all the points.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # K-means algorithm

# %% [markdown]
# Step 1:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 2:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
